# %% [markdown]
# # Assignment: Data Wrangling
# ## `! git clone https://github.com/DS3001/wrangling`
# ## Do Q2, and one of Q1 or Q3.

# %%
! git clone https://github.com/DS3001/wrangling
# Out:
# Cloning into 'wrangling'...
# remote: Enumerating objects: 83, done.
# remote: Counting objects: 100% (40/40), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 83 (delta 31), reused 11 (delta 11), pack-reused 43
# Receiving objects: 100% (83/83), 10.85 MiB | 23.68 MiB/s, done.
# Resolving deltas: 100% (36/36), done.

# %% [markdown]
# **Q1.** Open the "tidy_data.pdf" document in the repo, which is a paper called Tidy Data by Hadley Wickham.
#
#  1. Read the abstract. What is this paper about?
#
#   This paper talks about making data tidy by making sure the structure is the same (each variable a columb, each observation a rowm and each type of observational unit a table). This allows efficient data cleaning and analysis as well as opening the door for more analysis tools.
#
#  2. Read the introduction. What is the "tidy data standard" intended to accomplish?
#
#   Because data cleaning is time consuming and tedious, tidy data standard aims to make data cleaning and analysis more efficient by structuring the datasets.
#
#  3. Read the intro to section 2. What does this sentence mean: "Like families, tidy datasets are all alike but every messy dataset is messy in its own way." What does this sentence mean: "For a given dataset, it’s usually easy to figure out what are observations and what are variables, but it is surprisingly difficult to precisely define variables and observations in general."
#
#   With the quote under section 2 as well, I'd say happy families have certain fundemental aspects within their family so they communicate and live coherently and fulfillingly. Just like tidied data has fundamental aspects that allow everything to run smoothly. But messy or unhappy families lack those aspects and structures and they are all to different degrees or because of different reasons, just like data could be.
#
#    It's easy to say what is the row(observation) and column (variables) but defining that in itself can be difficult. I think some variables/observations can have challenging relationships or are subjectively complex to assign recordings that you have to your matrix. What makes a variable or how should we compare groups are some of the questions.
#
#
#  4. Read Section 2.2. How does Wickham define values, variables, and observations?
#
#   **Variable** - all values that measure the sae underlying attribute (height, temp) across units
#
#   **observation** - all values measured on the sae unit (like a person, or a race) across attributes
#
#   **value** - belongs to a variable and an observation - the recorded data.
#
#  5. How is "Tidy Data" defined in section 2.3?
#
#   Tidy Data has the same structure: each variable forms a column, each observation forms a row, and each type of observational unit forms a table. Then cherry on top if the variables were ordered from fixed to measured variables, it makes scanning them easy.
#
#  6. Read the intro to Section 3 and Section 3.1. What are the 5 most common problems with messy datasets? Why are the data in Table 4 messy? What is "melting" a dataset?
#
#   5 most common problems: column headers are values, not variable names. multiple variables are stored in one column, variables are stored in both rows and coluns, multuple types of observational units are stored in the same table. A single observational unit is stored in multiple tables. Table 4 is messy because they're using the common, presenter way of having rows and columns as variables. The rows are different religions when that should be under columns as well as income being multiple columns when it should be one. You melt a dataset when you turn the rows to columns - first specifying the colvars (columns that are already variables) then converting the rest of the columns into 2 variables (one for repreted colun headings and another containing the corresponding values).
#
#  7. Why, specifically, is table 11 messy but table 12 tidy and "molten"?
#
#   Table 11's columns are days which is not a variables. Table 12 has melted the days into one column called dates and tidy data took the elements column (figure out y)
#
#
#  8. Read Section 6. What is the "chicken-and-egg" problem with focusing on tidy data? What does Wickham hope happens in the future with further work on the subject of data wrangling?
#
#   The chicken-and-egg problem here is concerned that the usefulness of tidy data depends on the tools that can effectively navigate it. Wickham believes tidy data to be a foundational starting point for better data analysis. He wants to the expertise of statisticians and cognitive factors for the design of tidy data or forming alternatives and expanding efficiency to the other parts of data cleaning as well.

# %% [markdown]
# **Q2.** This question provides some practice cleaning variables which have common problems.
# 1. Numeric variable: For `./data/airbnb_hw.csv`, clean the `Price` variable as well as you can, and explain the choices you make. How many missing values do you end up with? (Hint: What happens to the formatting when a price goes over 999 dollars, say from 675 to 1,112?)
#
# **I'm sorry I can't find this csv file but I see how this was acheived in the solutions**
#   - read the csv, look at the first 5 rows and the columns names, checked the unique prices we have to see theyre saved as strings, took out commas to convert to numbers, then finally asked missing values

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# 2. Categorical variable: For the `./data/sharks.csv` data covered in the lecture, clean the "Type" variable as well as you can, and explain the choices you make.

# %% [markdown]
# Below, I first put Boat, Boating, and the typo Boatomg into the column Boating, while compliing invalid, questionable, unconfirmed, unverified and under investigation to convert them to missing values. Lastly, I put Watercraft and Sea disaster into Other water-related column. This allowed cleaning of repetitive or unclear data.

# %%
df = pd.read_csv('/content/wrangling/data/sharks.csv', low_memory=False)

# %%
cn = df.columns.tolist()
print(cn)
df.head()
# Out:
# ['index', 'Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity', 'Name', 'Unnamed: 9', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href', 'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22', 'Unnamed: 23', 'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27', 'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31', 'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41', 'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44', 'Unnamed: 45', 'Unnamed: 46', 'Unnamed: 47', 'Unnamed: 48', 'Unnamed: 49', 'Unnamed: 50', 'Unnamed: 51', 'Unnamed: 52', 'Unnamed: 53', 'Unnamed: 54', 'Unnamed: 55', 'Unnamed: 56', 'Unnamed: 57', 'Unnamed: 58', 'Unnamed: 59', 'Unnamed: 60', 'Unnamed: 61', 'Unnamed: 62', 'Unnamed: 63', 'Unnamed: 64', 'Unnamed: 65', 'Unnamed: 66', 'Unnamed: 67', 'Unnamed: 68', 'Unnamed: 69', 'Un
# ...

# %%
type = df['Type']
type = type.replace (['Boat', 'Boating', 'Boatomg'], 'Boating')
type = type.replace (['Invalid', 'Questionable', 'Unconfirmed', 'Unverified', 'Under Investigation'], np.nan)
type = type.replace (['Sea Disaster', 'Watercraft'], 'Other Water-related')
type.value_counts()
# Out:
# Unprovoked             4716
# Provoked                593
# Other Water-related     381
# Boating                 202
# Under investigation       1
# Name: Type, dtype: int64

# %% [markdown]
# 3. Dummy variable: For the pretrial data covered in the lecture, clean the `WhetherDefendantWasReleasedPretrial` variable as well as you can, and, in particular, replace missing values with `np.nan`.

# %% [markdown]
# Extracting "whetherdefendantwasreleasedpretrial", I saw which values were unique and counted those. Then replaced the 9's with a missing value and counted how many of those there were, using sum.

# %%
df = pd.read_csv ('/content/October 2017 Cohort_Virginia Pretrial Data Project_Deidentified FINAL Update_10272021.csv', low_memory=False)
cn = df.columns.tolist()
print(cn)
# Out:
# ['InternalStudyID', 'REQ_REC#', 'Defendant_Sex', 'Defendant_Race', 'Defendant_BirthYear', 'Defendant_Age', 'Defendant_AgeGroup', 'Defendant_AgeatCurrentArrest', 'Defendant_AttorneyTypeAtCaseClosure', 'Defendant_IndigencyStatus', 'Defendant_RecordedZipCode_eMag', 'Defendant_VirginiaResidencyStatus', 'WhetherDefendantWasReleasedPretrial', 'PretrialReleaseDate', 'DaysBetweenContactEventAndPretrialRelease', 'PretrialReleaseType1', 'PretrialReleaseType2', 'BondTypeAtInitialContact', 'BondAmountAtInitialContact', 'BondTypeAtRelease_v1', 'BondTypeatRelease_v2', 'BondAmountAtRelease', 'WhetherDefendantReceivedPretrialServicesAgencySuperv_PTCC', 'DaysBetweenReleaseandActivePretrialServicesAgencySupervDate', 'DaysBetweenPretrialServicesAgencySupervReferralDateandSupervDate', 'Indicator_PresumptiveDenialOfBail_19.2_120', 'Indicator_ConditionsToBeReleasedSecuredBond_19.2_123', 'IfReleasedonSecuredBond_TypeofSurety', 'Indicator_BailTermSetByCourt_eMag', 'AdditionalJailTimeServedAfterInitialPretri
# ...

# %%
df.head()
# Out:
#   InternalStudyID REQ_REC# Defendant_Sex Defendant_Race Defendant_BirthYear  \
# 0        ADI00001        1             M              W                1986
# 1        ADI00007        3             M              B                1956
# 2        ADI00008        4             M              W                1990
# 3        CDI00036        6             M              B                1989
# 4        CDI00038        7             F              W                1988
#
#   Defendant_Age  Defendant_AgeGroup Defendant_AgeatCurrentArrest  \
# 0            31                   3                           31
# 1            60                   6                           60
# 2            27                   3                           27
# 3            27                   3                           27
# 4            28                   3                           28
#
#    Defendant_AttorneyTypeAtCaseClosure  Defendant_IndigencyStatus  ...  \
# ...

# %%
release = df['WhetherDefendantWasReleasedPretrial']
print(release.unique(), '\n')
print(release.value_counts())
# Out:
# [9 0 1]
#
# 1    19154
# 0     3801
# 9       31
# Name: WhetherDefendantWasReleasedPretrial, dtype: int64

# %%
release = release.replace(9, np.nan)
print(release.value_counts())
# Out:
# 1.0    19154
# 0.0     3801
# Name: WhetherDefendantWasReleasedPretrial, dtype: int64

# %%
sum(release.isnull())
df['WhetherDefendantWasReleasedPretrial'] = release
del release

# %% [markdown]
# 4. Missing values, not at random: For the pretrial data covered in the lecture, clean the `ImposedSentenceAllChargeInContactEvent` variable as well as you can, and explain the choices you make. (Hint: Look at the `SentenceTypeAllChargesAtConvictionInContactEvent` variable.)

# %% [markdown]
# Change the values to numeric and calculate number of missing values. then made a crosstab of issing values and masked values of 4 with 0 as they were dismissed and replaced 9 with np.nan. Recalculate missing values.

# %%
df['ImposedSentenceAllChargeInContactEvent']
# Out:
# 0
# 1                      60
# 2                      12
# 3        .985626283367556
# 4
#                ...
# 22981
# 22982
# 22983
# 22984
# 22985
# Name: ImposedSentenceAllChargeInContactEvent, Length: 22986, dtype: object

# %%
df['SentenceTypeAllChargesAtConvictionInContactEvent']
# Out:
# 0        9
# 1        0
# 2        1
# 3        1
# 4        4
#         ..
# 22981    4
# 22982    9
# 22983    4
# 22984    4
# 22985    4
# Name: SentenceTypeAllChargesAtConvictionInContactEvent, Length: 22986, dtype: int64

# %%
length = df['ImposedSentenceAllChargeInContactEvent']
type = df ['SentenceTypeAllChargesAtConvictionInContactEvent']
print(length.unique())
# Out:
# [' ' '60' '12' '.985626283367556' '36' '6' '24' '5.91375770020534' '120'
#  '72' '11.9917864476386' '0' '2.95687885010267' '84' '108' '300' '240'
#  '180' '4' '96' '2' '54' '.328542094455852' '44' '5' '115' '132' '48'
#  '258' '34' '76' '.164271047227926' '.131416837782341' '111' '9' '3'
#  '1.97125256673511' '36.9856262833676' '.0657084188911704'
#  '35.4928131416838' '106.492813141684' '8' '35' '18.3141683778234' '480'
#  '32' '93' '234' '732' '1.16427104722793' '4.6570841889117' '21' '7'
#  '4.49281314168378' '18' '600' '43.1642710472279' '179' '52' '30' '20'
#  '192' '702' '14' '55' '53' '11.9055441478439' '114' '35.0061601642711'
#  '68' '.657084188911704' '46.6242299794661' '102' '65' '200' '57'
#  '24.3285420944559' '12.1642710472279' '117' '81.4928131416838'
#  '22.4928131416838' '1980' '3.6570841889117' '56' '10' '2.79260780287474'
#  '1' '47' '22' '1500' '40' '284' '11' '118' '42' '162' '156'
#  '47.2956878850103' '105' '51' '246' '29' '75' '324' '360'
# ...

# %%
length = pd.to_numeric(length, errors = 'coerce')
length_NA = length.isnull()
print(np.sum(length_NA))
# Out:
# 9053

# %%
print (pd.crosstab(length_NA, type))
# Out:
# SentenceTypeAllChargesAtConvictionInContactEvent     0     1    2     4    9
# ImposedSentenceAllChargeInContactEvent
# False                                             8720  4299  914     0    0
# True                                                 0     0    0  8779  274

# %%
length = length.mask (type == 4, 0 )
length = length.mask ( type == 9, np.nan)

length_NA = length.isnull()
print(pd.crosstab(length_NA, type))
print( np.sum(length_NA))
# Out:
# SentenceTypeAllChargesAtConvictionInContactEvent     0     1    2     4    9
# ImposedSentenceAllChargeInContactEvent
# False                                             8720  4299  914  8779    0
# True                                                 0     0    0     0  274
# 274

# %%
df['ImposedSentenceAllChargeInContactEvent'] = length
del length

# %% [markdown]
# **Q3.** Many important datasets contain a race variable, typically limited to a handful of values often including Black, White, Asian, Latino, and Indigenous. This question looks at data gathering efforts on this variable by the U.S. Federal government.
#
# 1. How did the most recent US Census gather data on race?
# 2. Why do we gather these data? What role do these kinds of data play in politics and society? Why does data quality matter?
# 3. Please provide a constructive criticism of how the Census was conducted: What was done well? What do you think was missing? How should future large scale surveys be adjusted to best reflect the diversity of the population? Could some of the Census' good practices be adopted more widely to gather richer and more useful data?
# 4. How did the Census gather data on sex and gender? Please provide a similar constructive criticism of their practices.
# 5. When it comes to cleaning data, what concerns do you have about protected characteristics like sex, gender, sexual identity, or race? What challenges can you imagine arising when there are missing values? What good or bad practices might people adopt, and why?
# 6. Suppose someone invented an algorithm to impute values for protected characteristics like race, gender, sex, or sexuality. What kinds of concerns would you have?
